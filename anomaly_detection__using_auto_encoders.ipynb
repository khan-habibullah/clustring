# %% [markdown]
# <a href="https://colab.research.google.com/github/khan-habibullah/clustring/blob/main/anomaly_detection__using_auto_encoders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
# %matplotlib inline
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 14, 8
RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %%
df = pd.read_csv("/content/creditcard.csv")
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %%
frauds.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
data = df.drop(['Time'], axis=1)
data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)
y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)
X_train = X_train.values
X_test = X_test.values
X_train.shape
# Out:
# (227451, 29)

# %%
input_dim = X_train.shape[1]
encoding_dim = 14
input_layer = Input(shape=(input_dim, ))
encoder = Dense(encoding_dim, activation="tanh",
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)
decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
nb_epoch = 100
batch_size = 32
autoencoder.compile(optimizer='adam',
                    loss='mean_squared_error',
                    metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 7108/7108 [==============================] - 36s 5ms/step - loss: 0.8370 - accuracy: 0.5672 - val_loss: 0.8204 - val_accuracy: 0.6221
# Epoch 2/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7807 - accuracy: 0.6253 - val_loss: 0.8009 - val_accuracy: 0.6342
# Epoch 3/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7691 - accuracy: 0.6340 - val_loss: 0.7939 - val_accuracy: 0.6418
# Epoch 4/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7635 - accuracy: 0.6395 - val_loss: 0.7914 - val_accuracy: 0.6446
# Epoch 5/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7605 - accuracy: 0.6431 - val_loss: 0.7890 - val_accuracy: 0.6406
# Epoch 6/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.7587 - accuracy: 0.6452 - val_loss: 0.7881 - val_accuracy: 0.6424
# Epoch 7/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7574 - accuracy: 0.6475 - val_loss: 0.7862 - val_accuracy: 0.6477
# Epoch 8/100
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.7563 - accuracy: 0.6485 - val_loss: 0.7857 - val_accuracy: 0.6510
# Epoch 9/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7558 - accuracy: 0.6498 - val_loss: 0.7896 - val_accuracy: 0.6475
# Epoch 10/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7552 - accuracy: 0.6507 - val_loss: 0.7854 - val_accuracy: 0.6521
# Epoch 11/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7541 - accuracy: 0.6504 - val_loss: 0.7846 - val_accuracy: 0.6488
# Epoch 12/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7536 - accuracy: 0.6520 - val_loss: 0.7833 - val_accuracy: 0.6495
# Epoch 13/100
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.7530 - accuracy: 0.6508 - val_loss: 0.7826 - val_accuracy: 0.6515
# Epoch 14/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7526 - accuracy: 0.6508 - val_loss: 0.7826 - val_accuracy: 0.6509
# Epoch 15/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7523 - accuracy: 0.6503 - val_loss: 0.7856 - val_accuracy: 0.6397
# Epoch 16/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7520 - accuracy: 0.6514 - val_loss: 0.7819 - val_accuracy: 0.6508
# Epoch 17/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7518 - accuracy: 0.6520 - val_loss: 0.7849 - val_accuracy: 0.6486
# Epoch 18/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7513 - accuracy: 0.6521 - val_loss: 0.7809 - val_accuracy: 0.6513
# Epoch 19/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7510 - accuracy: 0.6531 - val_loss: 0.7811 - val_accuracy: 0.6532
# Epoch 20/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7507 - accuracy: 0.6540 - val_loss: 0.7815 - val_accuracy: 0.6558
# Epoch 21/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7505 - accuracy: 0.6553 - val_loss: 0.7803 - val_accuracy: 0.6529
# Epoch 22/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7500 - accuracy: 0.6568 - val_loss: 0.7807 - val_accuracy: 0.6611
# Epoch 23/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7499 - accuracy: 0.6583 - val_loss: 0.7827 - val_accuracy: 0.6533
# Epoch 24/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7318 - accuracy: 0.6927 - val_loss: 0.7581 - val_accuracy: 0.7059
# Epoch 25/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7276 - accuracy: 0.7020 - val_loss: 0.7606 - val_accuracy: 0.6909
# Epoch 26/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7263 - accuracy: 0.7028 - val_loss: 0.7561 - val_accuracy: 0.7052
# Epoch 27/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7251 - accuracy: 0.7042 - val_loss: 0.7540 - val_accuracy: 0.7031
# Epoch 28/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7239 - accuracy: 0.7068 - val_loss: 0.7556 - val_accuracy: 0.7078
# Epoch 29/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7232 - accuracy: 0.7062 - val_loss: 0.7542 - val_accuracy: 0.7130
# Epoch 30/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7227 - accuracy: 0.7085 - val_loss: 0.7530 - val_accuracy: 0.7077
# Epoch 31/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7226 - accuracy: 0.7093 - val_loss: 0.7524 - val_accuracy: 0.7115
# Epoch 32/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7223 - accuracy: 0.7090 - val_loss: 0.7526 - val_accuracy: 0.7089
# Epoch 33/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7222 - accuracy: 0.7097 - val_loss: 0.7540 - val_accuracy: 0.7096
# Epoch 34/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7218 - accuracy: 0.7102 - val_loss: 0.7527 - val_accuracy: 0.7103
# Epoch 35/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7218 - accuracy: 0.7099 - val_loss: 0.7526 - val_accuracy: 0.7121
# Epoch 36/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7217 - accuracy: 0.7107 - val_loss: 0.7548 - val_accuracy: 0.7093
# Epoch 37/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7217 - accuracy: 0.7100 - val_loss: 0.7518 - val_accuracy: 0.7138
# Epoch 38/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7216 - accuracy: 0.7099 - val_loss: 0.7529 - val_accuracy: 0.7060
# Epoch 39/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7214 - accuracy: 0.7099 - val_loss: 0.7518 - val_accuracy: 0.7142
# Epoch 40/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7213 - accuracy: 0.7103 - val_loss: 0.7521 - val_accuracy: 0.7136
# Epoch 41/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7212 - accuracy: 0.7114 - val_loss: 0.7532 - val_accuracy: 0.7157
# Epoch 42/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7212 - accuracy: 0.7100 - val_loss: 0.7534 - val_accuracy: 0.7102
# Epoch 43/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7210 - accuracy: 0.7106 - val_loss: 0.7533 - val_accuracy: 0.7087
# Epoch 44/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7211 - accuracy: 0.7105 - val_loss: 0.7539 - val_accuracy: 0.6981
# Epoch 45/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7211 - accuracy: 0.7109 - val_loss: 0.7525 - val_accuracy: 0.7129
# Epoch 46/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7210 - accuracy: 0.7117 - val_loss: 0.7528 - val_accuracy: 0.7130
# Epoch 47/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7211 - accuracy: 0.7113 - val_loss: 0.7519 - val_accuracy: 0.7170
# Epoch 48/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7211 - accuracy: 0.7119 - val_loss: 0.7523 - val_accuracy: 0.7069
# Epoch 49/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7214 - accuracy: 0.7114 - val_loss: 0.7521 - val_accuracy: 0.7105
# Epoch 50/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7207 - accuracy: 0.7107 - val_loss: 0.7542 - val_accuracy: 0.7115
# Epoch 51/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7208 - accuracy: 0.7112 - val_loss: 0.7531 - val_accuracy: 0.7144
# Epoch 52/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7209 - accuracy: 0.7107 - val_loss: 0.7553 - val_accuracy: 0.7107
# Epoch 53/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7207 - accuracy: 0.7116 - val_loss: 0.7526 - val_accuracy: 0.7137
# Epoch 54/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7208 - accuracy: 0.7106 - val_loss: 0.7516 - val_accuracy: 0.7172
# Epoch 55/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7208 - accuracy: 0.7115 - val_loss: 0.7523 - val_accuracy: 0.7186
# Epoch 56/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7207 - accuracy: 0.7116 - val_loss: 0.7630 - val_accuracy: 0.7058
# Epoch 57/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7206 - accuracy: 0.7118 - val_loss: 0.7551 - val_accuracy: 0.7041
# Epoch 58/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7206 - accuracy: 0.7117 - val_loss: 0.7524 - val_accuracy: 0.7127
# Epoch 59/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7205 - accuracy: 0.7120 - val_loss: 0.7558 - val_accuracy: 0.7079
# Epoch 60/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7207 - accuracy: 0.7114 - val_loss: 0.7540 - val_accuracy: 0.7092
# Epoch 61/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7205 - accuracy: 0.7118 - val_loss: 0.7559 - val_accuracy: 0.7121
# Epoch 62/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7207 - accuracy: 0.7113 - val_loss: 0.7514 - val_accuracy: 0.7191
# Epoch 63/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7205 - accuracy: 0.7121 - val_loss: 0.7548 - val_accuracy: 0.6987
# Epoch 64/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7204 - accuracy: 0.7121 - val_loss: 0.7535 - val_accuracy: 0.7070
# Epoch 65/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7207 - accuracy: 0.7124 - val_loss: 0.7528 - val_accuracy: 0.7112
# Epoch 66/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7204 - accuracy: 0.7117 - val_loss: 0.7532 - val_accuracy: 0.7101
# Epoch 67/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7205 - accuracy: 0.7128 - val_loss: 0.7519 - val_accuracy: 0.7125
# Epoch 68/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7206 - accuracy: 0.7115 - val_loss: 0.7526 - val_accuracy: 0.7157
# Epoch 69/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7205 - accuracy: 0.7123 - val_loss: 0.7529 - val_accuracy: 0.7073
# Epoch 70/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7203 - accuracy: 0.7128 - val_loss: 0.7529 - val_accuracy: 0.7148
# Epoch 71/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7207 - accuracy: 0.7121 - val_loss: 0.7520 - val_accuracy: 0.7139
# Epoch 72/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7203 - accuracy: 0.7127 - val_loss: 0.7555 - val_accuracy: 0.7030
# Epoch 73/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7203 - accuracy: 0.7131 - val_loss: 0.7534 - val_accuracy: 0.7174
# Epoch 74/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7204 - accuracy: 0.7128 - val_loss: 0.7557 - val_accuracy: 0.7106
# Epoch 75/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7203 - accuracy: 0.7134 - val_loss: 0.7516 - val_accuracy: 0.7172
# Epoch 76/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7204 - accuracy: 0.7129 - val_loss: 0.7536 - val_accuracy: 0.7132
# Epoch 77/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7202 - accuracy: 0.7129 - val_loss: 0.7545 - val_accuracy: 0.7096
# Epoch 78/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7202 - accuracy: 0.7129 - val_loss: 0.7524 - val_accuracy: 0.7187
# Epoch 79/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7203 - accuracy: 0.7133 - val_loss: 0.7525 - val_accuracy: 0.7155
# Epoch 80/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7201 - accuracy: 0.7129 - val_loss: 0.7534 - val_accuracy: 0.7093
# Epoch 81/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7202 - accuracy: 0.7129 - val_loss: 0.7521 - val_accuracy: 0.7186
# Epoch 82/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7200 - accuracy: 0.7126 - val_loss: 0.7541 - val_accuracy: 0.7173
# Epoch 83/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7200 - accuracy: 0.7130 - val_loss: 0.7560 - val_accuracy: 0.7139
# Epoch 84/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7202 - accuracy: 0.7122 - val_loss: 0.7534 - val_accuracy: 0.7157
# Epoch 85/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7202 - accuracy: 0.7133 - val_loss: 0.7522 - val_accuracy: 0.7135
# Epoch 86/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7201 - accuracy: 0.7139 - val_loss: 0.7524 - val_accuracy: 0.7166
# Epoch 87/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7201 - accuracy: 0.7136 - val_loss: 0.7520 - val_accuracy: 0.7140
# Epoch 88/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7201 - accuracy: 0.7140 - val_loss: 0.7522 - val_accuracy: 0.7161
# Epoch 89/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7200 - accuracy: 0.7130 - val_loss: 0.7540 - val_accuracy: 0.7116
# Epoch 90/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7202 - accuracy: 0.7121 - val_loss: 0.7514 - val_accuracy: 0.7183
# Epoch 91/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7198 - accuracy: 0.7132 - val_loss: 0.7523 - val_accuracy: 0.7168
# Epoch 92/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7200 - accuracy: 0.7123 - val_loss: 0.7528 - val_accuracy: 0.7105
# Epoch 93/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7199 - accuracy: 0.7129 - val_loss: 0.7526 - val_accuracy: 0.7160
# Epoch 94/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7199 - accuracy: 0.7132 - val_loss: 0.7516 - val_accuracy: 0.7193
# Epoch 95/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7202 - accuracy: 0.7131 - val_loss: 0.7516 - val_accuracy: 0.7190
# Epoch 96/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7198 - accuracy: 0.7134 - val_loss: 0.7518 - val_accuracy: 0.7103
# Epoch 97/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7199 - accuracy: 0.7132 - val_loss: 0.7510 - val_accuracy: 0.7187
# Epoch 98/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7200 - accuracy: 0.7129 - val_loss: 0.7521 - val_accuracy: 0.7173
# Epoch 99/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7198 - accuracy: 0.7130 - val_loss: 0.7512 - val_accuracy: 0.7194
# Epoch 100/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7197 - accuracy: 0.7128 - val_loss: 0.7545 - val_accuracy: 0.6988

# %%
autoencoder = load_model('model.h5')

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 1781/1781 [==============================] - 2s 1ms/step
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.750085      0.001720
# std                3.587021      0.041443
# min                0.057810      0.000000
# 25%                0.243505      0.000000
# 50%                0.384773      0.000000
# 75%                0.607316      0.000000
# max              297.704182      1.000000

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %%
threshold = 2.9

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();
